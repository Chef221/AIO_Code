# %% [markdown]
# # (1) Recursion
#
# **1.Recursion**
#
# - A programming technique that breaks down a complex problem into smaller manageble pieces
# - Recursive solutions solve a problem by applying the same algorithm to each piece then combining the results

# %%
# Sum function
def countSum(arr):
